# %%
import sys, os, git, time

current_path = os.getcwd()
git_repo = git.Repo(current_path, search_parent_directories=True)
git_path = git_repo.git.rev_parse("--show-toplevel")
sys.path.append(git_path+"/python-codes/python-codes/")

from InitializeSimulation import InitializeSimulation
from Utilities import Utilities
from Outputs import Outputs
from MolecularDynamics import MolecularDynamics
from MonteCarlo import MonteCarlo

import numpy as np

# %%
self = MolecularDynamics(number_atoms=[100],
                      epsilon=[0.1], # kcal/mol
                      sigma=[3], # A
                      atom_mass=[1], # g/mol
                      atom_charge=[0], # in elementary charge units
                      Lx=30, # A
                      Ly=30, # A
                      Lz=30, # A
                      minimization_steps = 50,
                      maximum_steps=500,
                      desired_temperature=80,
                      thermo = 10,
                      dump = 10,  
                      tau_temp = 100, # fs
                      tau_press= 1000, # fs
                      time_step=1, # fs
                      seed=319817,
                      data_folder = "mdcode-output/",
                      )
self.run()
# run lammps for comparison
os.system("/home/simon/Softwares/lammps-2Aug2023/src/lmp_serial -in input.lammps > /dev/null")
# Out:
# step epot maxF
# 0 12978141.999 693925862.805
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 20
#       1 self = MolecularDynamics(number_atoms=[100],
#       2                       epsilon=[0.1], # kcal/mol
#       3                       sigma=[3], # A
#    (...)
#      18                       data_folder = "mdcode-output/",
#      19                       )
# ---> 20 self.run()
#      21 # run lammps for comparison
#      22 os.system("/home/simon/Softwares/lammps-2Aug2023/src/lmp_serial -in input.lammps > /dev/null")
#
# File ~/Git/PythonMD/applications/python-codes/python-codes/MolecularDynamics.py:42, in MolecularDynamics.run(self)
#      41 def run(self):
# ---> 42     self.perform_energy_minimization()
#      43     for self.step in range(0, self.maximum_steps+1):
#      44         self.update_neighbor_lists()
#
# File ~/Git/PythonMD/applications/python-codes/python-codes/Utilities.py:33, in Utilities.perform_energy_minimization(self, displacement)
#      31     displacement *= 0.2
#      32 self.update_log(minimization = True)
# ---> 33 self.update_dump(filename="dump.min.lammpstrj",
#      34                  velocity=False, minimization = True)
#
# File ~/Git/PythonMD/applications/python-codes/python-codes/Outputs.py:143, in Outputs.update_dump(self, filename, velocity, minimization)
#     141 if self.step % dumping == 0:
#     142     if self.step==0:
# --> 143         f = open(self.data_folder + filename, "w")
#     144     else:
#     145         f = open(self.data_folder + filename, "a")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mdcode-output/dump.min.lammpstrj'
