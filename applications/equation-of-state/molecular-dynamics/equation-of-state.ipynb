# %%
import sys, os, git, time, shutil

current_path = os.getcwd()
git_repo = git.Repo(current_path, search_parent_directories=True)
git_path = git_repo.git.rev_parse("--show-toplevel")
sys.path.append(git_path+"/python-codes/python-codes/")

from InitializeSimulation import InitializeSimulation
from Utilities import Utilities
from Outputs import Outputs
from MolecularDynamics import MolecularDynamics
from MonteCarlo import MonteCarlo

import numpy as np
from scipy import constants as cst

# %%
sigma = 3 # Angstrom
epsilon = 0.1 # Kcal/mol
mass = 1 # g/mol
kB = cst.Boltzmann*cst.Avogadro/cst.calorie/cst.kilo # kCal/mol/K
reference_temperature = epsilon/kB # K
N_atoms = 50
T_star = 2*reference_temperature

# %%
for rho_star in np.arange(0.1, 0.71, 0.2):
    desired_L_star = (N_atoms/rho_star)**(1/3)
    desired_L = desired_L_star * sigma
    self = MolecularDynamics(number_atoms=[N_atoms],
                        epsilon=[epsilon], # kcal/mol
                        sigma=[sigma], # A
                        atom_mass=[mass], # g/mol
                        Lx=desired_L, # A
                        minimization_steps = 50,
                        maximum_steps=20000,
                        desired_temperature=T_star,
                        thermo=200,
                        dump=1000,  
                        tau_temp=100, # fs
                        tau_press = None, # fs
                        time_step=1, # fs
                        data_folder = "mdcode-output/",
                        )
    self.run()
    shutil.copytree("mdcode-output/", "mdcode-rho"+str(np.round(rho_star,3)))

# %%
for rho_star in np.arange(0.03, 0.94, 0.02):
    desired_L_star = (N_atoms/rho_star)**(1/3)
    desired_L = desired_L_star * sigma
    self = MolecularDynamics(number_atoms=[N_atoms],
                        epsilon=[epsilon], # kcal/mol
                        sigma=[sigma], # A
                        atom_mass=[mass], # g/mol
                        Lx=desired_L, # A
                        minimization_steps = 0,
                        maximum_steps=0,
                        desired_temperature=T_star,
                        thermo=200,
                        dump=1000,  
                        tau_temp=100, # fs
                        tau_press = None, # fs
                        time_step=1, # fs
                        data_folder = "mdcode-output/",
                        )
    self.run()
    # run lammps for comparison
    os.system("/home/simon/Softwares/lammps-2Aug2023/src/lmp_serial -in input.lammps > /dev/null")
    shutil.copytree("lammps-output/", "lammps-rho"+str(np.round(rho_star,3)))
# Out:
# step epot maxF
# 0 0.493 9.263
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.01e+02  25.1      4.5e+04   0.439         14.8          0.00185
# step epot maxF
# 0 6.101 39.831
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.03e+02  1.13e+02  2.7e+04   5.78          15.0          0.00308
# step epot maxF
# 0 27.982 182.186
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.44e+02  4.06e+02  1.93e+04  20.7          21.0          0.00431
# step epot maxF
# 0 150.153 738.270
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    4.77e+02  1.81e+03  1.5e+04   75.6          69.7          0.00554
# step epot maxF
# 0 15408.888 271861.454
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.52e+07  8.24e+06  1.23e+04  40.6          2.21e+06      0.00677
# step epot maxF
# 0 2146.010 12471.410
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.03e+22  2.81e+22  2.45e+03  4.91e+05      1.51e+21      0.0338
# step epot maxF
# 0 275355309.107 13351540938.611
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.11e+16  3.12e+16  2.37e+03  2.74e+04      1.62e+15      0.0351
# step epot maxF
# 0 222353673.303 28761375050.048
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.6e+16   4.68e+16  2.29e+03  1.01e+04      2.34e+15      0.0363
# step epot maxF
# 0 1170933.218 11623472.003
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    2.11e+12  6.37e+12  2.21e+03  4.41e+06      3.08e+11      0.0375
# step epot maxF
# 0 24481934793.454 8206278678415.642
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.13e+21  3.52e+21  2.14e+03  3.1e+10       1.65e+20      0.0387
# step epot maxF
# 0 46491818.404 2353734272.549
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    2.86e+14  9.2e+14   2.08e+03  1.16e+07      4.18e+13      0.04
# step epot maxF
# 0 199478612.827 6953031343.474
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    4.65e+15  1.54e+16  2.01e+03  2.52e+05      6.8e+14       0.0412
# step epot maxF
# 0 98684232924.627 137794529269260.609
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    8.74e+21  2.98e+22  1.96e+03  1.21e+05      1.28e+21      0.0424
# step epot maxF
# 0 1030246.062 20742770.090
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    5.89e+10  2.07e+11  1.9e+03   4.57e+04      8.6e+09       0.0437
# step epot maxF
# 0 3705050.305 160019653.960
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.92e+12  6.94e+12  1.85e+03  1.02e+05      2.81e+11      0.0449
# step epot maxF
# 0 584423852492.823 585560880203641.000
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    4.13e+23  1.53e+24  1.8e+03   2.5e+06       6.03e+22      0.0461
# step epot maxF
# 0 3977737220.382 1158281131503.870
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    8.24e+18  3.14e+19  1.75e+03  1.59e+05      1.2e+18       0.0474
# step epot maxF
# 0 458395556.014 19676880554.012
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    3.13e+16  1.22e+17  1.71e+03  8.68e+05      4.57e+15      0.0486
# step epot maxF
# 0 75611415.529 4195222296.402
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.02e+15  4.09e+15  1.67e+03  2.01e+07      1.49e+14      0.0498
# step epot maxF
# 0 870817686.116 106313377528.407
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    1.83e+31  7.51e+31  1.63e+03  1.98e+15      2.67e+30      0.051
# step epot maxF
# 0 216500670.525 21449045097.872
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    5.26e+16  2.21e+17  1.59e+03  4.64e+08      7.68e+15      0.0523
# step epot maxF
# 0 425971374.152 45315163073.862
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    6.44e+16  2.77e+17  1.55e+03  3.65e+05      9.4e+15       0.0535
# step epot maxF
# 0 1400593.917 11973342.274
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    4.1e+10   1.8e+11   1.52e+03  3.28e+05      5.99e+09      0.0547
# step epot maxF
# 0 110538.596 693582.088
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    4.52e+13  2.03e+14  1.48e+03  2e+07         6.6e+12       0.056
# step epot maxF
# 0 395005058.904 17277727848.376
# step  N     T (K)     p (atm)   V (A3)    Ep (kcal/mol) Ek (kcal/mol) dens (g/cm3)
# 0     50    2.12e+16  9.77e+16  1.45e+03  1.26e+07      3.1e+15       0.0572
